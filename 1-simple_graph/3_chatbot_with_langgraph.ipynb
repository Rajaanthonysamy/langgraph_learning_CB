# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import os

# %%
apikey= os.getenv("OPENAI_API_KEY")

# %%
from langchain.chat_models import init_chat_model
llm = init_chat_model("llama-3.3-70b-versatile",model_provider="groq")

# %%
llm.invoke("Hi")
# Out:
# AIMessage(content="It's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 36, 'total_tokens': 59, 'completion_time': 0.050160438, 'prompt_time': 0.006353385, 'queue_time': 0.060345184, 'total_time': 0.056513823}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_fb4860a75b', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--c5868723-ee01-4e18-9da5-315d9767e91f-0', usage_metadata={'input_tokens': 36, 'output_tokens': 23, 'total_tokens': 59})

# %%
from typing_extensions import TypedDict
from langchain.chat_models import init_chat_model
from langgraph.graph import StateGraph ,START, END 
from langgraph.graph.message import add_messages

# %%
class State(TypedDict):
    messages : list 


def chatbot(state: State) -> State:
    return {"messages":[llm.invoke(state["messages"])]}


builder = StateGraph(State)

builder.add_node("chatbot_node",chatbot)


builder.add_edge(START,"chatbot_node")
builder.add_edge("chatbot_node",END)

graph = builder.compile()

# %%
message = {"role": "user","content":"Hi what is today?"}
response_msg = graph.invoke({"messages": [message]})

response_msg["messages"]
# Out:
# [AIMessage(content='Today is November 13, 2025.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 40, 'total_tokens': 51, 'completion_time': 0.039956642, 'prompt_time': 0.001679126, 'queue_time': 0.065393034, 'total_time': 0.041635768}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_0ca3f8c386', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--c80ec2fd-92a0-40d0-b1fe-ee5e39eca67c-0', usage_metadata={'input_tokens': 40, 'output_tokens': 11, 'total_tokens': 51})]

# %%
from typing_extensions import TypedDict , Annotated
from langchain.chat_models import init_chat_model
from langgraph.graph import StateGraph ,START, END 
from langgraph.graph.message import add_messages

# %%
class State(TypedDict):
    messages : Annotated[list,add_messages] 


def chatbot(state: State) -> State:
    return {"messages":[llm.invoke(state["messages"])]}


builder = StateGraph(State)

builder.add_node("chatbot_node",chatbot)


builder.add_edge(START,"chatbot_node")
builder.add_edge("chatbot_node",END)

graph = builder.compile()

# %%
message = {"role": "user","content":"Hi what is today?"}
response_msg = graph.invoke({"messages": [message]})

response_msg["messages"]
# Out:
# [HumanMessage(content='Hi what is today?', additional_kwargs={}, response_metadata={}, id='41fc363b-0faf-4051-854a-a370b8105ef5'),
#  AIMessage(content='Today is Friday, November 13, 2025.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 40, 'total_tokens': 53, 'completion_time': 0.054051133, 'prompt_time': 0.000916699, 'queue_time': 0.056492221, 'total_time': 0.054967832}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_fb4860a75b', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--a654df84-14b0-4539-b7e5-ad3eef6f051d-0', usage_metadata={'input_tokens': 40, 'output_tokens': 13, 'total_tokens': 53})]
